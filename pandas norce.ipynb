# %%
##pandas --> pandas is a open sorce library that is used for handle data manipulations

# %%
#data strucutre of pandas
#(1)series --> it is one dimensional array that is shows only value not column namme
#(2)dataframe--> it is multidimensional array that is shows value with column nmame

# %%
import pandas as pd

# %% [markdown]
# # (1)SERIES

# %%
a =pd.Series([1,4,576,45])
a
# Out:
# 0      1
# 1      4
# 2    576
# 3     45
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Dataframe

# %%
#with dictionary used
a ={
    "ID":[1,2,3],
    "Name":["sam" ,"raj" ,"Ankit"],
    "Section" :["A" ,"B" ,"C"]
}
df =pd.DataFrame(a)
df
# Out:
#    ID   Name Section
# 0   1    sam       A
# 1   2    raj       B
# 2   3  Ankit       C

# %% [markdown]
# # How to export our data

# %%
df.to_csv("student_of_advanced.csv" ,index =False)

# %% [markdown]
# # how to import data

# %%
df =pd.read_csv("placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head() #top 5
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail() #bottom 5
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe() #statically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info() #data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df =df.iloc[:4,:3] #iloc[row range ,column range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3 ,["cgpa" ,"placed"]]
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
s =df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p =df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b =df.empty 
b

###it returns true if there any missing data in dataframe otherwiae rerunr false
# Out:
# False

# %%
df.isnull().sum() ##for chrcking missing vslues
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna() ##for removing missing values
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i =df.ndim ##number of axes
i
# Out:
# 2

# %%
t =df.shape   #row count*column count
t
# Out:
# (100, 3)

# %%
df.size #get a array for numpy
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
a =df.values
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df= df.copy()

# %%
p =df.sort_values(by ="resume_score")
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
import pandas as pd
df =pd.read_csv("placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head(3)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1

# %%
df["cgpa"] =df["cgpa"].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df["cgpa"] =df["cgpa"].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
g =df.filter(items =["cgpa" ,"placed"])
g
df[["cgpa" ,"placed"]] ##second option of filtering
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
s =df.filter(items =[5,6] ,axis =0)
s
# Out:
#    cgpa  resume_score  placed
# 5    12          6.19       1
# 6     9          7.09       0

# %%
p =df.rename(columns ={"cgpa":"updated_cgpa" ,"resume_score ":"semester_marks"})
p
# Out:
#     updated_cgpa  resume_score  placed  half
# 0             12          6.52       1    12
# 1             10          5.17       0    10
# 2             12          8.86       1    12
# 3             10          7.27       1    10
# 4             11          7.30       1    11
# ..           ...           ...     ...   ...
# 95            10          6.38       0    10
# 96            12          7.76       1    12
# 97            10          7.78       0    10
# 98            12          5.63       1    12
# 99            10          6.61       0    10
#
# [100 rows x 4 columns]

# %%
df["half"] =df["cgpa"].where(df["cgpa"]>7 ,other =0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0    12          6.52       1    12
# 1    10          5.17       0    10
# 2    12          8.86       1    12
# 3    10          7.27       1    10
# 4    11          7.30       1    11
# 5    12          6.19       1    12
# 6     9          7.09       0     9
# 7    10          6.29       0    10
# 8    10          6.71       0    10
# 9    11          7.12       1    11
